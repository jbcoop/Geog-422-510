# %%
from ipyleaflet import Map, basemaps, Marker

center = (30.267153, -97.743057)
zoom = 15 # Define the zoom level

m = Map(
    basemap=basemaps.Esri.NatGeoWorldMap, center=center, zoom=zoom
)

marker = Marker(location=center, draggable=False)
m.add(marker)

m
# Out:
# Map(center=[30.267153, -97.743057], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…
